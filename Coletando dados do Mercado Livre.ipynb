# %%
import requests
from bs4 import BeautifulSoup

# %%
bairros = {"vila_mariana": "https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana",
           "campo_belo": "https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/",
           "moema": "https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/",
          "Jardim Vila Mariana": "https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/",
          "Vila Clementino": "https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/"}
n_paginas = 5

# %%
resultados = []
for bairro,url in bairros.items():
    for pagina in range(n_paginas):
        print(f"bairro: {bairro}, pagina: {pagina}, url: {url}")
        response = requests.get(url, timeout=5)
        soup = BeautifulSoup(response.content)
        lista_de_urls = soup.find_all("a", class_="ui-search-result__content ui-search-link")
        lista_de_urls = [w["href"] for w in lista_de_urls]
        lista_de_precos = soup.find_all("span", class_="price-tag-fraction")
        lista_de_precos = [w.text for w in lista_de_precos]
        lista_de_nomes = soup.find_all("h2", class_="ui-search-item__title ui-search-item__group__element")
        lista_de_nomes = [w.text for w in lista_de_nomes]
        lista_de_enderecos = soup.find_all("span", class_="ui-search-item__group__element ui-search-item__location")
        lista_de_enderecos = [w.text for w in lista_de_enderecos]
        area_quartos = soup.find_all("ul", class_="ui-search-card-attributes ui-search-item__group__element")
        lista_de_areas = [w.find_all("li")[0].text for w in area_quartos]
        lista_de_quartos = [w.find_all("li")[1].text if len(w.find_all("li"))>=2 else "sem_quartos" for w in area_quartos]
        lista_de_bairro = [bairro] * len(lista_de_urls)
        lista_de_resultados = list(zip(lista_de_bairro, lista_de_urls, lista_de_precos, lista_de_nomes, lista_de_enderecos, lista_de_areas, lista_de_quartos))
        resultados = resultados + lista_de_resultados
        next_page = (soup.find("a", title="Seguinte")["href"])
        url = next_page
print(f"Total de resultados: {len(resultados)}")
# Out:
# bairro: vila_mariana, pagina: 0, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana
# bairro: vila_mariana, pagina: 1, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana_Desde_49
# bairro: vila_mariana, pagina: 2, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana_Desde_97
# bairro: vila_mariana, pagina: 3, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana_Desde_145
# bairro: vila_mariana, pagina: 4, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-mariana_Desde_193
# bairro: campo_belo, pagina: 0, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/
# bairro: campo_belo, pagina: 1, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/_Desde_49
# bairro: campo_belo, pagina: 2, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/_Desde_97
# bairro: campo_belo, pagina: 3, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/_Desde_145
# bairro: campo_belo, pagina: 4, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/campo-belo/_Desde_193
# bairro: moema, pagina: 0, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/
# bairro: moema, pagina: 1, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/_Desde_49
# bairro: moema, pagina: 2, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/_Desde_97
# bairro: moema, pagina: 3, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/_Desde_145
# bairro: moema, pagina: 4, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/moema/_Desde_193
# bairro: Jardim Vila Mariana, pagina: 0, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/
# bairro: Jardim Vila Mariana, pagina: 1, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/_Desde_49
# bairro: Jardim Vila Mariana, pagina: 2, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/_Desde_97
# bairro: Jardim Vila Mariana, pagina: 3, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/_Desde_145
# bairro: Jardim Vila Mariana, pagina: 4, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/jardim-vila-mariana/_Desde_193
# bairro: Vila Clementino, pagina: 0, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/
# bairro: Vila Clementino, pagina: 1, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/_Desde_49
# bairro: Vila Clementino, pagina: 2, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/_Desde_97
# bairro: Vila Clementino, pagina: 3, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/_Desde_145
# bairro: Vila Clementino, pagina: 4, url: https://imoveis.mercadolivre.com.br/apartamentos/venda/sao-paulo/sao-paulo-zona-sul/vila-clementino/_Desde_193
# Total de resultados: 1200

# %%
import pandas as pd

# %%
pd.DataFrame(resultados).to_csv("resultadosfinal.csv")

# %%
pd.read_csv("resultados.csv")
# Out:
#      Unnamed: 0             0  \
# 0             0  vila_mariana
# 1             1  vila_mariana
# 2             2  vila_mariana
# 3             3  vila_mariana
# 4             4  vila_mariana
# ..          ...           ...
# 715         715         moema
# 716         716         moema
# 717         717         moema
# 718         718         moema
# 719         719         moema
#
#                                                      1          2  \
# 0    https://apartamento.mercadolivre.com.br/MLB-18...    690.000
# 1    https://apartamento.mercadolivre.com.br/MLB-19...    900.000
# 2    https://apartamento.mercadolivre.com.br/MLB-17...    356.186
# 3    https://apartamento.mercadolivre.com.br/MLB-16...    800.000
# 4    https://apartamento.mercadolivre.com.br/MLB-16...  2.900.000
# ..                                                 ...        ...
# 715  https://apartamento.mercadolivre.com.br/MLB-15...    960.000
# 716  https://apartamento.mercadolivre.com.br/MLB-15...  2.300.000
# 717  https://apartamento.mercadolivre.com.br/MLB-15...  2.800.000
# 718  https://apartamento.mercadolivre.com.br/MLB-15...  4.500.000
# 719  https://apartamento.mercadolivre.com.br/MLB-15...  4.000.000
#
#                                                      3  \
# 0    Apartamento Com 2 Dormitórios, 50 M² - Venda P...
# 1             Apartamento A Venda Em São Paulo - 26322
# 2                                   INSPIRE IBIRAPUERA
# 3    Apartamento Com 3 Dormitórios À Venda, 84 M² P...
# 4    Apartamento Duplex Com 4 Dormitórios À Venda, ...
# ..                                                 ...
# 715          Apartamento - Moema Índios  - Sp - 596603
# 716        Apartamento - Moema Pássaros  - Sp - 542553
# 717        Apartamento - Moema Pássaros  - Sp - 564636
# 718        Apartamento - Moema Pássaros  - Sp - 562834
# 719        Apartamento - Moema Pássaros  - Sp - 558620
#
#                                                      4  \
# 0    Rua Jorge Tibiriçá, Vila Mariana, São Paulo Zo...
# 1    Rua Gama Lobo, Vila Mariana, São Paulo Zona Su...
# 2          Vila Mariana, São Paulo Zona Sul, São Paulo
# 3          Vila Mariana, São Paulo Zona Sul, São Paulo
# 4    Jardim Vila Mariana, São Paulo Zona Sul, São P...
# ..                                                 ...
# 715  Av Chibarás, Moema, São Paulo Zona Sul, São Paulo
# 716  Al Jauaperi, Moema, São Paulo Zona Sul, São Paulo
# 717  Al Dos Arapanés, Moema, São Paulo Zona Sul, Sã...
# 718  R Ministro Gabriel De Rezende Passos, Moema, S...
# 719    R Gaivota, Moema, São Paulo Zona Sul, São Paulo
#
#                           5             6
# 0         50 m² construídos     2 quartos
# 1        101 m² construídos     3 quartos
# 2    25 - 51 m² construídos  1 - 2 dorms.
# 3         84 m² construídos     3 quartos
# 4        283 m² construídos     4 quartos
# ..                      ...           ...
# 715       90 m² construídos     3 quartos
# 716      298 m² construídos     4 quartos
# 717      187 m² construídos     4 quartos
# 718      340 m² construídos     4 quartos
# 719      298 m² construídos     4 quartos
#
# [720 rows x 8 columns]
